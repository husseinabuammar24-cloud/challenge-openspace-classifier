# %% [markdown]
# # Open Space Organizer
#
# We want to create a program that assigns 24 people to 6 tables in an openspace. Before getting started, take inventory what do we need:
#
# - People
# - Seats & Tables
# - An OpenSpace
#
# It's a good practice to start simple while you grasp the logic of the program you are trying to build and test often. For us this can translate to,
#
# - People -> List of Names (later we can figure out how to use a file)
# - Seats & Tables -> Class
# - An OpenSpace -> Class
#
# Below I've created a list of your new colleagues for reference!

# %%
new_collegues = ["Anna", "Dan", "Gaetan", "Guillermo", "Gunay", 
                         "Hiba", "Hussein", "Ibrahim", "Ibtihel", "Imad", "Iness", 
                         "Irene","Jeong", "Mahalakshmi", "Max", "Neha", "Siegried", 
                         "Sitara", "Sooyoung", "Stephane", "Thi", "Uzair", "Victor", "Vanessa"]

# %% [markdown]
# ## Step 1: Build a Seat
#
# Create a class called `Seat` with two attributes:
#
# - `free` which is a boolean.
# - `occupant` which is a string.
#
# and 2 methods (functions):
#
# - `set_occupant(name)` which allows the program to assign someone a seat if it's free
# - `remove_occupant()` which  remove someone from a seat and return the name of the person occupying the seat before

# %%
# Your code here
class Seat:
    def __init__(self):
        # A seat starts free
        self.free = True
        self.occupant = ""

    def set_occupant(self, name):
        # Assign someone if the seat is free
        if self.free:
            self.occupant = name
            self.free = False
            return True
        return False

    def remove_occupant(self):
        # Remove the occupant and return the name
        if not self.free:
            name = self.occupant
            self.occupant = ""
            self.free = True
            return name
        return None

# %%
# Test your code (assign yourself you a Seat)
my_seat = Seat()
my_seat.set_occupant("Hussein")
print(my_seat.occupant)
# Out:
# Hussein

# %%
seat1 = Seat()

seat1.set_occupant("Hussein")

print("Seat occupant:", seat1.occupant)
print("Is seat free?", seat1.free)

removed_person = seat1.remove_occupant()

print("Removed occupant:", removed_person)
print("Is seat free now?", seat1.free)
# Out:
# Seat occupant: Hussein
# Is seat free? False
# Removed occupant: Hussein
# Is seat free now? True

# %% [markdown]
# What is the input and the output of your Seat class? Does it make sense?
#
# ## Step 2: Build a Table
#
# Create a class `Table` with ? attributes:
#
# - `capacity` which is an integer
# - `seats` which is a list of `Seat` objects (size = `capacity`)
#
# and 3 methods (functions):
# - `has_free_spot()` that returns a boolean (True if a spot is available)
# - `assign_seat(name)` that places someone at the table
# - `left_capacity()` that returns an integer
#
# Question: Which attributes make sense to give? For now let's say we want to build 6 tables with 4 seats.
#
# # My answer is : capacity and seats attributes make sense to consider when building 6 tables with 4 seats.

# %%
# Your code here
class Table:
    def __init__(self, capacity=4):
        self.capacity = capacity
        self.seats = [Seat() for _ in range(capacity)]

    def has_free_spot(self):
        # True if at least one seat is free
        return any(seat.free for seat in self.seats)

    def assign_seat(self, name):
        # Put someone in the first free seat
        for seat in self.seats:
            if seat.free:
                seat.set_occupant(name)
                return True
        return False

    def left_capacity(self):
        # Count remaining free seats
        return sum(seat.free for seat in self.seats)

# %%
# Test your code (assign the colleagues at your table to a Table)

table1 = Table(4)

print("\nFree spots available?", table1.has_free_spot())

table1.assign_seat("Dan")
table1.assign_seat("Hiba")
table1.assign_seat("Max")
table1.assign_seat("Hussein")


print("Remaining free seats:", table1.left_capacity())

# Display occupants
for i, seat in enumerate(table1.seats, start=1):
    if seat.free:
        print(f"Seat {i}: Empty")
    else:
        print(f"Seat {i}: {seat.occupant}")
# Out:
# Free spots available? True
# Remaining free seats: 0
# Seat 1: Dan
# Seat 2: Hiba
# Seat 3: Max
# Seat 4: Hussein

# %% [markdown]
# Does the output of you test make sense? Check that each method returns the correct value.

# %% [markdown]
# ## Step 3: Build an OpenSpace
#
# Create a class `Openspace` that contains these attributes:
#
# - `tables` which is a list of `Table`.
# - `number_of_tables` which is an integer.
#
# And some methods:
#
# - `organize(names)` that will:
#   - **randomly** assign people to `Seat` objects in the different `Table` objects. (hint: explore the `random` library )
# - `display()` display the different tables and there occupants in a nice and readable way
# - `store(filename)` store the repartition in an file

# %%
# Your code here
import random

class OpenSpace:
    def __init__(self, number_of_tables = 6):
        self.number_of_tables = number_of_tables
        self.tables = [Table(capacity = 4) for _ in range(self.number_of_tables)]

    def organize(self,names):
        shuffled_names = names.copy()
        random.shuffle(shuffled_names)

        for name in shuffled_names:
            for table in self.tables:
                if table.has_free_spot():
                    table.assign_seat(name)
                    break
    
    def disply(self):
        print ("\n ***OpenSpace seating chart***")

        for index, table in enumerate (self.tables, 1):
            occupants = [seat.occupant for seat in table.seats if not seat.free] 

            if occupants:
                seats_str = ", ".join (occupants)
            else:
                seats_str = "Emptry Table"
                print(f"Table{index}, {seats_str}")
            print ("======================================")
    

    def store (self, filename):
        with open(filename, "w") as file:
            file.write("-***OpenSpace Seating Chart***-\n\n")
            for index, table in enumerate(self.tables, 1):
                occupants = [seat.occupant for seat in table.seats if not seat.free]
                seats_str = ", ".join(occupants) if occupants else "Empty Table"
                file.write(f"Table {index}: {seats_str}\n")
        print (f"Seating chart successfully saved to '{filename}'")

# %%
# Test your code (assign everyone in the class to a table)


# --- Execution and Testing ---
# to ensure code runs only when scipt is executed directly
if __name__ == "__main__":
        new_colleagues = [       # Defines a list containing 24 distinct colleague names
        "Anna", "Dan", "Gaetan", "Guillermo", "Gunay", "Hiba", 
        "Hussein", "Ibrahim", "Ibtihel", "Imad", "Iness", "Irene",
        "Jeong", "Mahalakshmi", "Max", "Neha", "Siegried", "Sitara", 
        "Sooyoung", "Stephane", "Thi", "Uzair", "Victor", "Vanessa"
    ]

# to make an office with 6 tables of 4 seats 
office = OpenSpace(number_of_tables = 6)

office. organize(new_colleagues)

office.disply()

office.store("Openspace_layout.text")
# Out:
#  ***OpenSpace seating chart***
# ...
# Seating chart successfully saved to 'Openspace_layout.text'

# %% [markdown]
# Hurray! You have the algorithm logic working. Next steps we transform this into some scripts! **Big note:** Once you move to the scrips you may need to adapt your logic.

# %% [markdown]
# ''' https://chatgpt.com/c/6a184f15-9bb0-83eb-87ef-7945c2c8f644
#
# To improve!
# Your code is already good object-oriented programming practice. Here are the main improvements you could make to make it cleaner and more “Pythonic”.
#
# 1. Give Seat default values directly in __init__
#
# Instead of:
#
# self.free = True
# self.occupant = ""
#
# you could allow optional values:
#
# def __init__(self, free=True, occupant=""):
#     self.free = free
#     self.occupant = occupant
#
# This makes the class more flexible.
#
# 2. Simplify remove_occupant()
#
# Your method is already good, but you can slightly simplify it:
#
# def remove_occupant(self):
#     name = self.occupant
#     self.occupant = ""
#     self.free = True
#     return name
#
# Because even if the seat is already free, returning "" is acceptable.
#
# 3. Improve assign_seat()
#
# Currently:
#
# return True
# return False
#
# works perfectly.
#
# But you could also print a message when the table is full:
#
# print("No free seats available.")
#
# Useful for debugging.
#
# 4. Add a method to display the table nicely
#
# Instead of repeating the loop outside the class, create a method:
#
# def display_seats(self):
#     for i, seat in enumerate(self.seats, start=1):
#         if seat.free:
#             print(f"Seat {i}: Empty")
#         else:
#             print(f"Seat {i}: {seat.occupant}")
#
# Then simply call:
#
# table1.display_seats()
#
# This is better encapsulation.
#
# 5. Use __str__() for cleaner printing
#
# Advanced but very useful.
#
# Inside Seat:
#
# def __str__(self):
#     return self.occupant if not self.free else "Empty"
#
# Then:
#
# print(seat)
#
# automatically prints nicely.
#
# 6. Use left_capacity() more explicitly
#
# Currently:
#
# sum(seat.free for seat in self.seats)
#
# works because:
#
# True == 1
# False == 0
#
# Very Pythonic.
#
# But for beginners, this is clearer:
#
# sum(1 for seat in self.seats if seat.free)
# 7. Add validation
#
# Example:
#
# prevent empty names
# prevent duplicate occupants
#
# Example:
#
# if not name:
#     return False
# 8. Best improvement: Remove redundancy
#
# Right now you store BOTH:
#
# free
# occupant
#
# But these represent the same information.
#
# A seat is free if:
#
# occupant == ""
#
# So you could completely remove free.
#
# Example:
#
# class Seat:
#     def __init__(self):
#         self.occupant = None
#
#     def is_free(self):
#         return self.occupant is None
#
# This avoids inconsistent states like:
#
# seat.free = True
# seat.occupant = "Ali"
#
# which should never happen.
#
# Most professional version
#
# Professional programmers would probably use:
#
# occupant = None
# a method is_free()
# __str__()
# display_seats()
#
# because it avoids duplicated state and makes the code safer.
#
# Your current code is already correct and good for learning classes and objects.'''
